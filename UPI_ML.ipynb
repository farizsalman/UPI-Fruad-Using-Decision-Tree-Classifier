# %%
# importing libraries
import pandas as pd
from sklearn.model_selection import train_test_split
import joblib

# %%
# loading the preprocessed dataset
UPI=pd.read_csv(r'C:\Users\salma\OneDrive\Desktop\UPI\UPI_Data.csv')
UPI
# Out:
#         transaction type  merchant_category  amount (INR)  transaction_status  \
# 0                    1.0                7.0           868                   1
# 1                    0.0                0.0          1011                   1
# 2                    1.0                0.0           477                   1
# 3                    1.0                3.0          2784                   1
# 4                    1.0                2.0           990                   1
# ...                  ...                ...           ...                 ...
# 249995               2.0                1.0           373                   1
# 249996               1.0                5.0          2025                   1
# 249997               1.0                1.0           468                   1
# 249998               2.0                8.0           284                   1
# 249999               1.0                7.0           531                   1
#
# ...

# %%
# splitting train and test data
x=UPI.drop('fraud_flag',axis=1)
y=UPI['fraud_flag']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,test_size=0.2,random_state=42)

# %%
# reducing the imbalance in data
from imblearn.over_sampling import SMOTE
sm= SMOTE(random_state=42)
x_resampled,y_resampled=sm.fit_resample(x_train,y_train)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
lr.fit(x_resampled,y_resampled)
# Out:
# c:\Users\salma\anaconda3\envs\upi_env\Lib\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
joblib.dump(lr,'Logitic_regression.pk1')
# Out:
# ['Logitic_regression.pk1']

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

# %%
dtc_model=DecisionTreeClassifier()

# %%
gscv=GridSearchCV(dtc_model,{'criterion': ['gini', 'entropy', 'log_loss'],
                     'max_depth': [None, 5, 10, 20],
                     'min_samples_split': [2, 5, 10],
                     'min_samples_leaf': [1, 2, 4]},
                  cv=5,return_train_score=True,n_jobs=-1)

# %%
#gscv.fit(x_resampled,y_resampled)

# %%
#gscv.best_params_

# %%
dtc_model=DecisionTreeClassifier(criterion = 'gini',max_depth = 5,min_samples_leaf = 2,min_samples_split = 10)

# %%
dtc_model.fit(x_resampled,y_resampled)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=2, min_samples_split=10)

# %%
joblib.dump(dtc_model,'Decision_Tree_Classifier.pk1')
# Out:
# ['Decision_Tree_Classifier.pk1']

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc_model=RandomForestClassifier()

# %%
gscv_rfc=GridSearchCV(rfc_model,{'criterion': ['gini', 'entropy', 'log_loss'],
                     'max_depth': [None, 5, 10, 20],
                     'min_samples_split': [2, 5, 10],
                     'min_samples_leaf': [1, 2, 4]},
                  n_jobs=-1,cv=5,return_train_score=True)

# %%
#gscv_rfc.fit(x_resampled,y_resampled)

# %%
#gscv_rfc.best_params_

# %%
rfc_model=RandomForestClassifier(criterion= 'gini',max_depth= None,min_samples_leaf= 1,min_samples_split= 2)
rfc_model.fit(x_resampled,y_resampled)
# Out:
# RandomForestClassifier()

# %%
joblib.dump(rfc_model,'Random_Forest_Classifier.pk1')
# Out:
# ['Random_Forest_Classifier.pk1']

# %% [markdown]
# # Linear Support Vector Classifier

# %%
from sklearn.svm import LinearSVC
from sklearn.model_selection import GridSearchCV

# %%
lsvc_model=LinearSVC(dual=False, max_iter=10000)

# %%
gscv_svc=GridSearchCV(lsvc_model,{'C': [0.1, 1, 10]},
                    n_jobs=-1,cv=5,return_train_score=True)

# %%
#gscv_svc.fit(x_train,y_train)

# %%
#gscv_svc.best_params_

# %%
lsvc_model=LinearSVC(C=0.1, dual=False, max_iter=10000)
lsvc_model.fit(x_resampled,y_resampled)
# Out:
# LinearSVC(C=0.1, dual=False, max_iter=10000)

# %%
joblib.dump(lsvc_model,'LinearSVC.pk1')
# Out:
# ['LinearSVC.pk1']

# %% [markdown]
# # XGBoost Classifier

# %%
#conda install -c conda-forge xgboost

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
xgbc_model=XGBClassifier(objective='binary:logistic',
    eval_metric='auc',
    use_label_encoder=False,
    n_jobs=-1,
    tree_method='hist' )

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [3, 5],
    'learning_rate': [0.05, 0.1],
    'scale_pos_weight': [24]
}

# %%
gscv_xgbc = GridSearchCV(
    estimator=xgbc_model,
    param_grid=param_grid,  
    cv=3,
    n_jobs=-1,
    scoring='roc_auc',
    return_train_score=True,
    verbose=2
)

# %%
#gscv_xgbc.fit(x_resampled, y_resampled)

# %%
#gscv_xgbc.best_params_

# %%
xgbc_model=XGBClassifier(learning_rate = 0.1,max_depth= 5, n_estimators=  200,scale_pos_weight =24)
xgbc_model.fit(x_resampled,y_resampled)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
joblib.dump(xgbc_model,"XGBClassifier.pk1")
# Out:
# ['XGBClassifier.pk1']

# %% [markdown]
# # Testing accuracy

# %%
import joblib
from sklearn.metrics import accuracy_score, roc_auc_score,f1_score

# %% [markdown]
# #### logistic regression

# %%
linearReg_model=joblib.load("Logitic_regression.pk1")

# %%
y_train_pred_lr=linearReg_model.predict(x_resampled)
y_test_pred_lr=linearReg_model.predict(x_test)

# %%
# train accuracy
print("Accuracy",accuracy_score(y_resampled,y_train_pred_lr))
print("Roc-Auc",roc_auc_score(y_resampled,y_train_pred_lr))
# Out:
# Accuracy 0.5514938682269959
# Roc-Auc 0.5514938682269959

# %%
# test accuracy
print("Accuracy",accuracy_score(y_test,y_test_pred_lr))
print("Roc-Auc",roc_auc_score(y_test,y_test_pred_lr))
# Out:
# Accuracy 0.54562
# Roc-Auc 0.46567242438815865

# %% [markdown]
# #### Decision Tree Classifier

# %%
dt_model=joblib.load("Decision_Tree_Classifier.pk1")

# %%
y_train_pred_dt=dt_model.predict(x_resampled)
y_test_pred_dt=dt_model.predict(x_test)

# %%
# train accuracy
print("Accuracy",accuracy_score(y_resampled,y_train_pred_dt))
print("Roc-Auc",roc_auc_score(y_resampled,y_train_pred_dt))
# Out:
# Accuracy 0.8231003526771401
# Roc-Auc 0.8231003526771401

# %%
# test accuracy
print("Accuracy",accuracy_score(y_test,y_test_pred_dt))
print("Roc-Auc ",roc_auc_score(y_test,y_test_pred_dt))
# Out:
# Accuracy 0.952
# Roc-Auc  0.5133038767767447

# %% [markdown]
# #### Random Forest Classifier

# %%
rf_model=joblib.load("Random_Forest_Classifier.pk1")

# %%
y_train_pred_rf=rf_model.predict(x_resampled)
y_test_pred_rf=rf_model.predict(x_test)

# %%
# train accuracy
print("Accuracy",accuracy_score(y_resampled,y_train_pred_rf))
print("Roc-Auc",roc_auc_score(y_resampled,y_train_pred_rf))
# Out:
# Accuracy 0.9999949903815325
# Roc-Auc 0.9999949903815326

# %%
# test accuracy
print("Accuracy",accuracy_score(y_test,y_test_pred_rf))
print("Roc-Auc",roc_auc_score(y_test,y_test_pred_rf))
# Out:
# Accuracy 0.99808
# Roc-Auc 0.5

# %% [markdown]
# #### Linear SVC  Classifier

# %%
svc_model=joblib.load("LinearSVC.pk1")

# %%
y_train_pred_svc=svc_model.predict(x_resampled)
y_test_pred_svc=svc_model.predict(x_test)

# %%
# train accuracy
print("Accuracy",accuracy_score(y_resampled,y_train_pred_svc))
print("Roc-Auc",roc_auc_score(y_resampled,y_train_pred_svc))
# Out:
# Accuracy 0.5527036910868868
# Roc-Auc 0.5527036910868868

# %%
# test accuracy
print("Accuracy",accuracy_score(y_test,y_test_pred_svc))
print("Roc-Auc",roc_auc_score(y_test,y_test_pred_svc))
# Out:
# Accuracy 0.57248
# Roc-Auc 0.4687316313989527

# %% [markdown]
# #### XGBClassifier

# %%
xgb_model=joblib.load("XGBClassifier.pk1")

# %%
y_train_pred_xgb=xgb_model.predict(x_resampled)
y_test_pred_xgb=xgb_model.predict(x_test)

# %%
# train accuracy
print("Accuracy",accuracy_score(y_resampled,y_train_pred_xgb))
print("Roc-Auc",roc_auc_score(y_resampled,y_train_pred_xgb))
# Out:
# Accuracy 0.9990055907342097
# Roc-Auc 0.9990055907342097

# %%
# test accuracy
print("Accuracy",accuracy_score(y_test,y_test_pred_xgb))
print("Roc-Auc",roc_auc_score(y_test,y_test_pred_xgb))
# Out:
# Accuracy 0.99782
# Roc-Auc 0.4998697499198461
